# %%
import pandas as pd

df = pd.read_csv("hf://datasets/bitext/Bitext-customer-support-llm-chatbot-training-dataset/Bitext_Sample_Customer_Support_Training_Dataset_27K_responses-v11.csv")

# %%
df.shape
# Out:
# (26872, 5)

# %%
df.head()
# Out:
#    flags                                        instruction category  \
# 0      B   question about cancelling order {{Order Number}}    ORDER
# 1    BQZ  i have a question about cancelling oorder {{Or...    ORDER
# 2   BLQZ    i need help cancelling puchase {{Order Number}}    ORDER
# 3     BL         I need to cancel purchase {{Order Number}}    ORDER
# 4  BCELN  I cannot afford this order, cancel purchase {{...    ORDER
#
#          intent                                           response
# 0  cancel_order  I've understood you have a question regarding ...
# 1  cancel_order  I've been informed that you have a question ab...
# 2  cancel_order  I can sense that you're seeking assistance wit...
# 3  cancel_order  I understood that you need assistance with can...
# 4  cancel_order  I'm sensitive to the fact that you're facing f...

# %%
df.groupby('category').count()
# Out:
#               flags  instruction  intent  response
# category
# ACCOUNT        5986         5986    5986      5986
# CANCEL          950          950     950       950
# CONTACT        1999         1999    1999      1999
# DELIVERY       1994         1994    1994      1994
# FEEDBACK       1997         1997    1997      1997
# INVOICE        1999         1999    1999      1999
# ORDER          3988         3988    3988      3988
# PAYMENT        1998         1998    1998      1998
# REFUND         2992         2992    2992      2992
# SHIPPING       1970         1970    1970      1970
# SUBSCRIPTION    999          999     999       999

# %%
df[df['category'] == 'CANCEL'].head()
# Out:
#       flags                                        instruction category  \
# 2968  BCLWZ  I can't ifnd the bloody termination charge, I ...   CANCEL
# 2969    BIL        what is the fee for canceling the contract?   CANCEL
# 2970   BILP               could I check the withdrawal charge?   CANCEL
# 2971    BLQ   i need help to see the early termination penalty   CANCEL
# 2972    BLQ          need assistance to see the withdrawal fee   CANCEL
#
#                       intent  \
# 2968  check_cancellation_fee
# 2969  check_cancellation_fee
# 2970  check_cancellation_fee
# 2971  check_cancellation_fee
# 2972  check_cancellation_fee
#
#                                                response
# 2968  No worries! I'll assist you in finding the ter...
# 2969  To inquire about the cancellation fee for your...
# 2970  Positively! I can help you with the informatio...
# 2971  Absolutely! To view the early termination pena...
# 2972  Indeed! I'm here to help you with checking the...

# %% [markdown]
# Буду использовать только категорию отмены

# %%
df = df[df['category'] == 'CANCEL'].copy()

# %%
df['instruction'].isna().sum()
# Out:
# np.int64(0)

# %%
df['instruction'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df["instruction_len"] = df["instruction"].astype(str).str.len()
df["response_len"] = df["response"].astype(str).str.len()

print(df["instruction_len"].mean())
print(df["response_len"].mean())

print(df[["instruction_len", "response_len"]].describe())
# Out:
# 43.96842105263158
# 260.8663157894737
#        instruction_len  response_len
# count       950.000000    950.000000
# mean         43.968421    260.866316
# std           8.629907    101.290660
# min          14.000000     58.000000
# 25%          38.000000    184.000000
# 50%          44.000000    249.000000
# 75%          50.750000    329.000000
# max          60.000000    638.000000

# %%
df["instruction_words"] = df["instruction"].astype(str).str.split().str.len()
df["response_words"] = df["response"].astype(str).str.split().str.len()

print(df["instruction_words"].mean())
print(df["response_words"].mean())

print(df[["instruction_words", "response_words"]].describe())
# Out:
# 8.16842105263158
# 43.92842105263158
#        instruction_words  response_words
# count         950.000000      950.000000
# mean            8.168421       43.928421
# std             2.302940       16.805436
# min             2.000000        9.000000
# 25%             7.000000       31.000000
# 50%             8.000000       42.000000
# 75%            10.000000       55.000000
# max            15.000000      103.000000

# %%
df.sort_values(by=['instruction_words'])
# Out:
#       flags                                        instruction category  \
# 3349    BLZ                                 withrdawal penalty   CANCEL
# 3330    BLM                                   termination fees   CANCEL
# 3359     BL                               cancellation penalty   CANCEL
# 3320    BLM                                termination charges   CANCEL
# 3719     BL                                     withdrawal fee   CANCEL
# ...     ...                                                ...      ...
# 3441    BEL  I do not know what I have to do to see the ter...   CANCEL
# 3829   BELQ  i do not know what i need to do to check the t...   CANCEL
# 3116    BLM  I don't know what I have to do to see the earl...   CANCEL
# 3655    BEL  I do not know what I need to do to see the ear...   CANCEL
# 3506  BELMQ  i do not know what i have to do to see the ear...   CANCEL
#
#                       intent  \
# 3349  check_cancellation_fee
# 3330  check_cancellation_fee
# 3359  check_cancellation_fee
# 3320  check_cancellation_fee
# 3719  check_cancellation_fee
# ...                      ...
# 3441  check_cancellation_fee
# 3829  check_cancellation_fee
# 3116  check_cancellation_fee
# 3655  check_cancellation_fee
# 3506  check_cancellation_fee
#
#                                                response  instruction_len  \
# 3349  Absolutely! To check the withdrawal penalty fo...               18
# 3330  I'm happy to help! I can help you with checkin...               16
# 3359  Unquestionably! Let me provide you with the de...               20
# 3320  Positively! To check the termination charges a...               19
# 3719  Certainly! The withdrawal fee for canceling yo...               14
# ...                                                 ...              ...
# 3441  No worries, I can guide you on how to check th...               58
# 3829  No worries, I'll guide you through the process...               60
# 3116  No problem! To view the early exit fees, you c...               57
# 3655  No problem! I can help you find the informatio...               60
# 3506  No problem! I can guide you through the proces...               58
#
#       response_len  instruction_words  response_words
# 3349           293                  2              44
# 3330           194                  2              33
# 3359           418                  2              66
# 3320           361                  2              59
# 3719           287                  2              45
# ...            ...                ...             ...
# 3441           270                 14              45
# 3829            79                 14              13
# 3116           205                 14              38
# 3655           241                 15              42
# 3506           456                 15              82
#
# [950 rows x 9 columns]

# %%
df.sort_values(by=['response_words'])
# Out:
#       flags                                        instruction category  \
# 3260    BLQ              i need help seeing the withdrawal fee   CANCEL
# 3605   BELQ   i do not know how to check the withdrawal charge   CANCEL
# 3882   BLMQ        i want help seeing the early exit penalties   CANCEL
# 3884    BLQ       want assistance seeing the withdrawal charge   CANCEL
# 3073   BILM             how to check the early exit penalties?   CANCEL
# ...     ...                                                ...      ...
# 3064    BLQ      need assistance seeing the withdrawal penalty   CANCEL
# 3745   BILM           can you help me see the withdrawal fees?   CANCEL
# 3111   BILM                      what are the withdrawal fees?   CANCEL
# 3250    BIL  what do I need to do to see the early terminat...   CANCEL
# 3814  BILMZ  what do I have to do to check the early exit f...   CANCEL
#
#                       intent  \
# 3260  check_cancellation_fee
# 3605  check_cancellation_fee
# 3882  check_cancellation_fee
# 3884  check_cancellation_fee
# 3073  check_cancellation_fee
# ...                      ...
# 3064  check_cancellation_fee
# 3745  check_cancellation_fee
# 3111  check_cancellation_fee
# 3250  check_cancellation_fee
# 3814  check_cancellation_fee
#
#                                                response  instruction_len  \
# 3260  Unquestionably! Let me help you check the with...               37
# 3605  Sure! Let me help you with checking the withdr...               48
# 3882  Definitely! I can help you review the early te...               43
# 3884  Positively! I'm here to assist you with viewin...               44
# 3073  Sure, I can assist you with verifying the earl...               38
# ...                                                 ...              ...
# 3064  Certainly! I can assist you in checking the wi...               45
# 3745  Of course, I'd be happy to help you understand...               40
# 3111  I'm on it! I can provide you with information ...               29
# 3250  Unquestionably! Let me guide you on the steps ...               58
# 3814  Sure! To check the early exit fees, you can fo...               51
#
#       response_len  instruction_words  response_words
# 3260            59                  7               9
# 3605            58                 10              10
# 3882            61                  8              10
# 3884            70                  6              11
# 3073            70                  7              11
# ...            ...                ...             ...
# 3064           600                  6              99
# 3745           632                  8             100
# 3111           631                  5             102
# 3250           612                 12             102
# 3814           638                 13             103
#
# [950 rows x 9 columns]

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

model_name = "mistralai/Mistral-7B-Instruct-v0.3"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.float16,
)

tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map="auto",
)
# Out:
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
